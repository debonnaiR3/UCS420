# %% [markdown]
# Q1. You are a data analyst at an e-commerce company. Your task is to analyze sales data,
# clean and process it, perform staƟsƟcal analysis, and generate visual insights to help the
# business make informed decisions.
# 1. Use your roll number as the random seed to generate unique data for each student.
# 2. Follow the quesƟons step by step, as each part builds upon the previous one.
# 3. Submit the assignment as a Jupyter Notebook (.ipynb) with:
#  Well-documented code and clear comments.
#  Markdown explanaƟons for each step.
#  Screenshots of the plots and outputs.
# Part I: Randomized Sales Data GeneraƟon (NumPy)
# 1. IniƟalize Random Seed
# 2. Generate Sales Data
#  Create a NumPy array of random sales data for 12 months (shape = (12, 4)),
# where each column represents a product category:
#  Electronics, Clothing, Home & Kitchen, Sports.
#  Sales values should be between 1000 and 5000 units per month.
#  The range should be randomized using the seed.
# 3. Convert to DataFrame
#  Convert the cleaned NumPy array into a Pandas DataFrame with:
# i. Columns: Electronics, Clothing, Home & Kitchen, Sports
# ii. Index: Months from Jan to Dec
# Part II: Data ManipulaƟon and Analysis (Pandas)
# 1. Display the first 5 rows and summary staƟsƟcs of the DataFrame.
# 2. Calculate the total sales per category and total sales per month.
# 3. Calculate the average sales growth between consecuƟve months for each category.
# 4. Add the following columns to the DataFrame:
#  Total Sales: Sum of all categories per month.
#  Growth Rate: Percentage change in Total Sales from the previous month.
# 5. Apply a randomized discount:
#  If your roll number is even, apply a 10% discount to the Electronics category.
#
#  If odd, apply a 15% discount to the Clothing category.
#
# Part III: VisualizaƟons (Matplotlib and Seaborn)
# 1. Plot monthly sales trends for each category using line plots.
# 2. Create the following plots:
#  Box plots to show the sales distribuƟon for each category.

# %%
# ANS 1.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Part I: Randomized Sales Data Generation (NumPy)
# Initialize Random Seed (replace with your roll number)
roll = 102317289  # Change this to your actual roll number
np.random.seed(roll)

# Generate Sales Data
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
cat = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]
sales= np.random.randint(1000, 5000, size=(12, 4))

# Convert to DataFrame
df = pd.DataFrame(sales, columns=cat, index=months)

# Part II: Data Manipulation and Analysis (Pandas)
# Display first 5 rows and summary statistics
print("First 5 Rows:\n", df.head())
print("\nSummary Statistics:\n", df.describe())

# Calculate total sales per category and per month
total_sales_per_category = df.sum()
total_sales_per_month = df.sum(axis=1)

df["Total Sales"] = total_sales_per_month

# Calculate average sales growth between consecutive months
df["Growth Rate"] = df["Total Sales"].pct_change() * 100

# Apply discount based on roll number
if roll % 2 == 0:
    df["Electronics"] *= 0.90  # 10% discount on Electronics
else:
    df["Clothing"] *= 0.85  # 15% discount on Clothing


# Part III: Visualizations (Matplotlib and Seaborn)
# Plot monthly sales trends
plt.figure(figsize=(10, 5))
for category in cat:
    plt.plot(df.index, df[category], marker='o', label=category)
plt.xlabel("Month")
plt.ylabel("Sales (units)")
plt.title("Monthly Sales Trends by Category")
plt.legend()
plt.grid()
plt.show()

# Box plots to show sales distribution
plt.figure(figsize=(8, 5))
sns.boxplot(data=df[cat])
plt.title("Sales Distribution by Category")
plt.ylabel("Sales (units)")
plt.show()

# Printing final DataFrame
df
# Out:
# First 5 Rows:
#       Electronics  Clothing  Home & Kitchen  Sports
# Jan         3467      2983            1802    4705
# Feb         3302      1174            1595    4055
# Mar         4714      2788            4831    2932
# Apr         4190      2998            3521    4177
# May         2527      4567            3722    1693
#
# Summary Statistics:
#         Electronics    Clothing  Home & Kitchen       Sports
# count    12.000000    12.00000       12.000000    12.000000
# mean   3833.583333  2665.25000     3492.500000  3051.666667
# std     810.010152  1163.41067     1357.955181  1168.416904
# min    2527.000000  1174.00000     1395.000000  1302.000000
# 25%    3235.750000  1469.50000     2154.500000  2177.250000
# 50%    3996.500000  2885.50000     3898.500000  2860.500000
# 75%    4584.250000  3456.25000     4657.250000  4160.500000
# max    4799.000000  4567.00000     4947.000000  4705.000000
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         3467   2535.55            1802    4705        12957          NaN
# Feb         3302    997.90            1595    4055        10126   -21.849193
# Mar         4714   2369.80            4831    2932        15265    50.750543
# Apr         4190   2548.30            3521    4177        14886    -2.482804
# May         2527   3881.95            3722    1693        12509   -15.968024
# Jun         4541   3481.60            4947    1761        15345    22.671676
# Jul         3833   2850.05            2272    2316        11774   -23.271424
# Aug         4714   1214.65            4630    4203        14976    27.195516
# Sep         3037   1260.55            1395    2789         8704   -41.880342
# Oct         4799   1156.85            4075    1302        11537    32.548254
# Nov         2719   3201.10            4739    4155        15379    33.301552
# Dec         4160   1687.25            4381    2532        13058   -15.092009

# %% [markdown]
# Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
# i. Find element-wise absolute value
# ii. Find the 25th, 50th, and 75th percenƟle of flaƩened array, for each column, for each
# row.
# iii. Mean, Median and Standard DeviaƟon of flaƩened array, of each column, and
# each row

# %%
# ANS 2.

import numpy as np
array = np.array([[1, -2, 3], [-4, 5, -6]])

abs_array = np.abs(array)
print("(i) Element-wise Absolute Value:\n", abs_array)

flattened_percentiles = np.percentile(array, [25, 50, 75])  # For the flattened array
col_percentiles = np.percentile(array, [25, 50, 75], axis=0)  # For each column
row_percentiles = np.percentile(array, [25, 50, 75], axis=1)  # For each row
print("(ii)")
print("\tPercentiles (Flattened):", flattened_percentiles)
print("\tPercentiles (Columns):\n", col_percentiles)
print("\tPercentiles (Rows):\n", row_percentiles)

mean_flattened = np.mean(array)
median_flattened = np.median(array)
std_flattened = np.std(array)

mean_columns = np.mean(array, axis=0)
median_columns = np.median(array, axis=0)
std_columns = np.std(array, axis=0)

mean_rows = np.mean(array, axis=1)
median_rows = np.median(array, axis=1)
std_rows = np.std(array, axis=1)
print("(iii)")
print("\tFlattened Mean:", mean_flattened)
print("\tFlattened Median:", median_flattened)
print("\tFlattened Standard Deviation:", std_flattened)

print("\tColumn-wise Mean:", mean_columns)
print("\tColumn-wise Median:", median_columns)
print("\tColumn-wise Standard Deviation:", std_columns)

print("\tRow-wise Mean:", mean_rows)
print("\tRow-wise Median:", median_rows)
print("\tRow-wise Standard Deviation:", std_rows)
# Out:
# (i) Element-wise Absolute Value:
#  [[1 2 3]
#  [4 5 6]]
# (ii)
# 	Percentiles (Flattened): [-3.5 -0.5  2.5]
# 	Percentiles (Columns):
# 	 [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# 	Percentiles (Rows):
# 	 [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# (iii)
# 	Flattened Mean: -0.5
# 	Flattened Median: -0.5
# 	Flattened Standard Deviation: 3.8622100754188224
# 	Column-wise Mean: [-1.5  1.5 -1.5]
# 	Column-wise Median: [-1.5  1.5 -1.5]
# 	Column-wise Standard Deviation: [2.5 3.5 4.5]
# 	Row-wise Mean: [ 0.66666667 -1.66666667]
# 	Row-wise Median: [ 1. -4.]
# 	Row-wise Standard Deviation: [2.05480467 4.78423336]

# %% [markdown]
# Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).
# i. Find floor, ceiling and truncated value, rounded values

# %%
# ANS 3.

import numpy as np

a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

print("Original Array:", a)
print("Floor Values:", np.floor(a))
print("Ceiling Values:", np.ceil(a))
print("Truncated Values:", np.trunc(a))
print("Rounded Values:", np.round(a))
# Out:
# Original Array: [-1.8 -1.6 -0.5  0.5  1.6  1.8  3. ]
# Floor Values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling Values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated Values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded Values: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.

# %%
# ANS 4.

def swap(lst, index1, index2):
    
    temp = lst[index1]
    lst[index1] = lst[index2]
    lst[index2] = temp

lst = [10, 20, 30, 40, 50]

print("Before Swap:", lst)
swap(lst, 1, 3)
print("After Swap:", lst)
# Out:
# Before Swap: [10, 20, 30, 40, 50]
# After Swap: [10, 40, 30, 20, 50]

# %% [markdown]
# Q.5 Write a Python program to swap two elements in a set by converƟng it to a list first.

# %%
# ANS 5.

def swap_set(s, elem1, elem2):
    lst = list(s)
    if elem1 in lst and elem2 in lst:
  
        index1, index2 = lst.index(elem1), lst.index(elem2)
        lst[index1], lst[index2] = lst[index2], lst[index1]
        return set(lst)
    else:
        print("Elements not found in the set.")
        return s

myset = {1, 2, 3, 4, 5}
print("Before Swap:", myset)
newset = swap_set(myset, 2, 4)
print("After Swap:", newset)
# Out:
# Before Swap: {1, 2, 3, 4, 5}
# After Swap: {1, 2, 3, 4, 5}
