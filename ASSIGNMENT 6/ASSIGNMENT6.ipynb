# %% [markdown]
# Q1. Ask the user to enter a value (e.g., M) for a mathematical function.
#  Generate x values from -10 to 10 using np.linspace().
#  Compute y values for:
#     o y= M⋅x2
#     o y=M⋅sin(x)
#  Plot both functions in a single figure:
#     o Use different colors and line styles.
#     o Add legend, grid, and title.

# %%
# ANS 1.

import numpy as np
import matplotlib.pyplot as plt

M = float(input("Enter the value of M: "))
x = np.linspace(-10, 10, 400)
ySqu = M * (x**2)
ySin = M * np.sin(x)

plt.figure(figsize=(8, 6))
plt.plot(x, ySqu, label=r'$y = Mx^2$', color='blue', linestyle='--')
plt.plot(x, ySin, label=r'$y = M\sin(x)$', color='red', linestyle='-')

plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Graphs of y = Mx^2 and y = Msin(x)")
plt.legend()
plt.grid(True)


plt.show()

# %% [markdown]
# Q.2 Create a dataset of five subjects and scores.
#  Convert it into a Pandas DataFrame.
#  Plot the scores using a Seaborn bar plot with:
#     o Different colors for each bar.
#     o Annotations on top of each bar.
#     o Title, axis labels, and grid.

# %%
# ANS 2.

import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt


df = pd.DataFrame({'Course': ['Math', 'Physics', 'Chemistry', 'Biology', 'English'],
                   'Marks': [99, 80, 78, 58, 62]})

plt.figure(figsize=(8, 5))
ax = sb.barplot(x='Course', y='Marks', hue='Course', data=df, palette='husl', legend=False)


for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.title("Marks in Different Courses", fontsize=14, fontweight='bold')
plt.xlabel("Courses")
plt.ylabel("Marks")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Q3. Write a Python script to select your roll number as seed for NumPy and
#     then generate a dataset of 50 values using np.random.randn().
#  Create a 2x2 subplot layout displaying:
#     o Line plot showing cumulative sum.
#     o Scatter plot with random noise.
#  Customize with titles, axis labels, and grids.

# %%
# ANS 3.

import numpy as np
import matplotlib.pyplot as plt

roll = 102317289
np.random.seed(roll)
data = np.random.randn(50)

fig, axis = plt.subplots(2, 2, figsize=(10, 8))
axis[0, 0].plot(np.cumsum(data), linestyle='-', color='black')
axis[0, 0].set_title("Cumulative Sum Plot")
axis[0, 0].set_xlabel("Index")
axis[0, 0].set_ylabel("Cumulative Sum")
axis[0, 0].grid(True)

noise = np.random.randn(50) * 0.5
axis[0, 1].scatter(range(50), data + noise, color='black', alpha=0.7)
axis[0, 1].set_title("Scatter Plot with Noise")
axis[0, 1].set_xlabel("Index")
axis[0, 1].set_ylabel("Value")
axis[0, 1].grid(True)

axis[1, 0].axis("off")
axis[1, 1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# Q.4 Download Data-set from the below link
#     https://github.com/AnjulaMehto/MCA/blob/main/company_sales_data.csv
#     Apply ‘seaborn’ library to do the following.
#     1. Read Total profit of all months and show it using a line plot.
#     2. Read all product sales data and show it using a multiline plot.
#     3. Plot bar chart for all the features/attributes.

# %%
# ANS 4.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


url = "https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv"
df = pd.read_csv(url)


plt.figure(figsize=(10, 5))
sns.lineplot(x=df["month_number"], y=df["total_profit"], marker="o", label="Total Profit", color="blue")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("1) Total Profit Per Month")
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 6))
for column in df.columns[1:-1]:  # Excluding 'month_number' and 'total_profit'
    sns.lineplot(x=df["month_number"], y=df[column], marker="o", label=column)
plt.xlabel("Month Number")
plt.ylabel("Sales")
plt.title("2) Sales of Different Products Per Month")
plt.legend()
plt.grid(True)
plt.show()


df.set_index("month_number").plot(kind="bar", figsize=(15, 6))
plt.xlabel("Month Number")
plt.ylabel("Values")
plt.title("3) Bar Chart of All Features")
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid(axis="y", linestyle="--")
plt.show()
